# %%
# 그래프 라이브러리
# matplotlib

# %% [markdown]
# # 데이터 시각화

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt

# %%
# 배열 생성하여 데이터 준비
x = np.arange(1,6)
np.random.seed(3) # 랜덤값을 고정
y = np.random.randint(1,10,size=5)
print(x)
print(y)
# Out:
# [1 2 3 4 5]
# [9 4 9 9 1]

# %%
# 선그래프 그리기
# plt.plot(x축데이터,y축데이터)
plt.plot(x,y)

# 주피터 노트북 , 구글colab 환경에서는 plot을 그릴때 별도의 코드 없이 그래프가 출력된다
# vscode pytorvh 등 pil.show()까지 작성
plt.show()

# %%
# 선 그리는 경우 x축 생략 가능함
plt.plot(y)
plt.show()

# %% [markdown]
# # 선 그래프의 옵션
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 선그래프 스타일 변경
# marker= 포인트에 스타일 변경
# ms= marker 사이즈
# mec = marker edge color = 색깔이니셜사용
# mew = marker...
# mfc = marker...
plt.plot(x,y,ls=":",marker='D',ms=10,mec='r',mew = 3,mfc='g')
plt.show()

# %% [markdown]
# ## 하나의 출력문에 여러개 그래프

# %%
plt.plot(x,y,ls = '-', color='b' ,marker='D', ms=10, mec='c',mew=4, mfc='y')
plt.plot(x,y, ls = '--', color='m', lw=5)
plt.plot(x,y, ls = '-.')
plt.plot(x,y, ls = ':')
plt.show()
# 별도의 코드기 없으면 겹쳐서 출력

# %% [markdown]
# ###  plt.subplot(row,col,index)
# - 행 열 인덱스

# %%
# 하나의 출력문에 여러개 그래프
# plt.subplot()

plt.subplot(3,2,1)  # 3행2열1번인덱스
plt.plot(x,y,ls = '-', color='b' ,marker='D', ms=10, mec='c',mew=4, mfc='y')

plt.subplot(3,2,2)
plt.plot(x,y, ls = '--', color='m', lw=5)

plt.subplot(3,2,3)
plt.plot(x,y, ls = '-.')

plt.subplot(3,2,4)
plt.plot(x,y, ls = ':')

plt.subplot(3,2,5)
plt.plot(x,y, ls = ':')

plt.subplot(3,2,6)
plt.plot(x,y, ls = ':')

plt.show()

# %%
# 배열 생성하여 데이터 준비
test_x = np.arange(1,6)
np.random.seed(4)
test_y = np.random.randint(1,10,size=5)
print(test_x)
print(test_y)
# Out:
# [1 2 3 4 5]
# [8 6 2 9 8]

# %%
plt.plot(test_x,test_y)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 그래프 제목 넣기 --> title()함수

plt.title('hello')
plt.plot(test_x,test_y)
plt.show()

# %%
# 격자눈금 -grid()
plt.grid()
plt.title('test')
plt.plot(test_x,test_y)
plt.show()

# %%
# 범례 -legend() 

test_x1 = np.arange(1,6)
np.random.seed(10)
test_y1 = np.random.randint(1,10,size=5)

plt.plot(test_x,test_y)
plt.plot(test_x1,test_y1)

plt.legend() # 라벨을 안주면 표현이 불완전
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 범례 -legend() ->두 개이상의 그래프 자료를 한 곳에 표현하는 것

test_x1 = np.arange(1,6)
np.random.seed(10)
test_y1 = np.random.randint(1,10,size=5)

# 등장하려면 plt.plot하는 구간에 lable를 작성
plt.plot(test_x,test_y,  label = 'test1')
plt.plot(test_x1,test_y1,label = 'test2')

# plt.plot() 다음에 plt.legend() 코드 작성하기 ***
plt.legend() # 등장하려면 plt.plot하는 구간에 lable를 작성

plt.show()

# %%
#한글 폰트 깨질 경우
# 내컴의 가장 기본 폰트인 Malgun Gothic로 한글 적용
# 다른 폰트가 있다면 영문으로 적으면 된다.
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
# x라벨 ,y라벨

plt.plot(test_x,test_y,label = 'test1')
plt.plot(test_x1,test_y1,label = 'test2')

plt.xlabel('x축')
plt.ylabel('y축',rotation=0,loc='top') # 기본값=90각도  rotation->라벨의 회전
# loc=은 라벨 위치 top ,bottom ,center
plt.show()

# %%
# xlim , ylim  -> 리미트의 약자
# xlim(n,n1) --> x축의 범위를 숫자로~

plt.plot(test_x,test_y,label = 'test1')
plt.plot(test_x1,test_y1,label = 'test2')

plt.xlim(0,10)
plt.ylim(0,10)
plt.show()

plt.xlim(0,3)
plt.ylim(0,5)
plt.show()

# %%
# plt.figure(figsize =(x,y))  --> 크기 -> 인치단위 

plt.figure(figsize = (10,3)) 

plt.plot(test_x,test_y,label = 'test1')
plt.plot(test_x1,test_y1,label = 'test2')

plt.show()

# %%
# xticks ,yticks  -> 축의 눈금의 범위 조정

plt.plot(test_x,test_y,label = 'test1')
plt.plot(test_x1,test_y1,label = 'test2')

# 리스트 혹은 배열을 넣는다
# 리스트 크기가 데이터의 갯수와는 상관이 없다
plt.xticks([1,2,3,4,5])
plt.yticks([1,3,5,7,9])

plt.show()

# %% [markdown]
# ### 인구변동 데이터

# %%
data1 = pd.read_csv('data/장래_인구변동_KOSIS.csv', encoding = 'euc-kr')
data1
# Out:
#     인구변동요인별   2020   2030   2040   2050   2060   2070
# 0    인구(천명)  51836  51199  50193  47359  42617  37656
# 1  출생아수(천명)    275    305    286    236    181    196
# 2  사망자수(천명)    308    408    527    680    741    702

# %%
# 자료의 한글이 있어 encoding = 'euc-kr'
# index_col = '컬럼명' 은 해당 컬럼을 인덱스로 사용한다 
data = pd.read_csv('data/장래_인구변동_KOSIS.csv', encoding = 'euc-kr', index_col = '인구변동요인별')
data
# Out:
#            2020   2030   2040   2050   2060   2070
# 인구변동요인별
# 인구(천명)    51836  51199  50193  47359  42617  37656
# 출생아수(천명)    275    305    286    236    181    196
# 사망자수(천명)    308    408    527    680    741    702

# %% [markdown]
# # 출생아수 ,사망자수를 데이터 시각화

# %%
# 연도별 출생아수 데이터 접근
data_y1 =data.iloc[1]  # 시리즈형식 #y축

#  연도별 사망자수 데이터 접근
data_y2 =data.iloc[2]  # =[2,:]   #y축

# %%
# 컬럼명을 x축으로
data_x = data.columns

# %%
plt.plot(data_x, data_y1, marker ='*', ms=10, label='출생아수(천명)')

plt.plot(data_x, data_y2, marker ='o', ms=8, label='사망자수(천명)')

# title
plt.title('국가통계 요인별 장애인구 동향')

# grid
plt.grid()

#legend - plt구간에 라벨 작성하기
plt.legend()


plt.show()

# %%
plt.plot(data_x, data_y1, marker = "*", ms = 10, label = "출생아수(천명)")

plt.plot(data_x, data_y2, marker = "o", ms = 8, label = "사망자수(천명)")

# title
plt.title('국가통계 요인별 장래 인구 동향')

# grid
plt.grid()

# legend - plot label 작성 해주기!
plt.legend()

# plt.show()

# 이미지 저장 (경로+파일명, dpi=인치당 노트(작성안하면 기본 해상도 높으면 고해상도), bbox_inches=기본값이tight -> 빈칸 최소화)  )
plt.savefig('./kosis 요인별 장래 인구 동향.png', dpi=600, bbox_inches='tight')

# %% [markdown]
# ### 기산청 api 데이터 그래프 작성하기

# %%
# skiprows=데이터에 행열(표)가 아닌 데이터가 있으면 그 부분은 표시하지 말아라
tdata = pd.read_csv('data/기상데이터.csv', encoding = 'euc-kr',skiprows = range(0,7))
tdata.head(2)
tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0     \t2010-01-01  156     -3.6     -9.5      1.9
# 1     \t2010-01-02  156      1.6     -3.9      6.6
# 2     \t2010-01-03  156      0.4     -1.8      3.5
# 3     \t2010-01-04  156      0.5     -1.8      5.7
# 4     \t2010-01-05  156     -3.0     -4.9      0.2
# ...            ...  ...      ...      ...      ...
# 5154  \t2024-02-11  156      3.2     -1.2      9.1
# 5155  \t2024-02-12  156      5.8     -0.9     13.0
# 5156  \t2024-02-13  156     10.6      3.4     17.6
# 5157  \t2024-02-14  156     13.5     10.6     19.0
# 5158  \t2024-02-15  156      6.4      0.5     12.4
#
# [5159 rows x 5 columns]

# %%
tdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5159 entries, 0 to 5158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       5159 non-null   object
#  1   지점       5159 non-null   int64
#  2   평균기온(℃)  5159 non-null   float64
#  3   최저기온(℃)  5159 non-null   float64
#  4   최고기온(℃)  5159 non-null   float64
#  5   월일       5159 non-null   object
#  6   월        5159 non-null   object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 282.3+ KB

# %%
# 최저기온 시각화
# 최저기온 데이터 접근
# t_y=tdata['최저기온(℃)']

# %%
#마이너스 기호 사용 코드
plt.rcParams['axes.unicode_minus'] = False

plt.plot(t_y)  # x축 생략
plt.show()

# %%
# 데이터 정제의 필요하다
# 날짜를-->월일로 담긴 파생변수
# 월일 이라는 파생변수


tdata['월일']=tdata['날짜'].str[-5:]
tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일
# 0     \t2010-01-01  156     -3.6     -9.5      1.9  01-01
# 1     \t2010-01-02  156      1.6     -3.9      6.6  01-02
# 2     \t2010-01-03  156      0.4     -1.8      3.5  01-03
# 3     \t2010-01-04  156      0.5     -1.8      5.7  01-04
# 4     \t2010-01-05  156     -3.0     -4.9      0.2  01-05
# ...            ...  ...      ...      ...      ...    ...
# 5154  \t2024-02-11  156      3.2     -1.2      9.1  02-11
# 5155  \t2024-02-12  156      5.8     -0.9     13.0  02-12
# 5156  \t2024-02-13  156     10.6      3.4     17.6  02-13
# 5157  \t2024-02-14  156     13.5     10.6     19.0  02-14
# 5158  \t2024-02-15  156      6.4      0.5     12.4  02-15
#
# [5159 rows x 6 columns]

# %%
# 본인 생일날짜 평균기온 연도별 그래프 시각화
#1.본인 생일날짜 블리언 인덱싱
# 데이터 접근부터 항상 먼저한다
tdata.query('월일=="01-28"')


birth_tdata = tdata.query('월일=="01-28"')
birth_tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일
# 27    \t2010-01-28  156      4.3      0.2      7.4  01-28
# 392   \t2011-01-28  156     -4.0     -6.8      0.5  01-28
# 757   \t2012-01-28  156      2.4     -1.0      9.0  01-28
# 1123  \t2013-01-28  156      0.0     -5.4      5.9  01-28
# 1488  \t2014-01-28  156      3.7     -0.6     10.4  01-28
# 1853  \t2015-01-28  156     -1.5     -4.8      4.2  01-28
# 2218  \t2016-01-28  156      2.6      0.4      4.8  01-28
# 2584  \t2017-01-28  156      3.4     -4.4     11.0  01-28
# 2949  \t2018-01-28  156     -1.1     -3.7      3.2  01-28
# 3314  \t2019-01-28  156      3.4     -0.1      8.5  01-28
# 3679  \t2020-01-28  156      7.3      3.7     13.0  01-28
# 4045  \t2021-01-28  156      0.7     -4.3      6.9  01-28
# 4410  \t2022-01-28  156      1.0     -1.5      5.8  01-28
# 4775  \t2023-01-28  156     -2.8     -7.7      1.9  01-28
# 5140  \t2024-01-28  156      1.8     -1.4      6.1  01-28

# %%
# 2. x,y축 설정
y=birth_tdata['평균기온(℃)']
x=range(2010,2025)

plt.plot(x,y)

plt.show()

# %% [markdown]
# ### 히스토그램
# - 분석의 분포도 파악이 주목적

# %%
# 데이터의 빈도를 막대 그래프 형태로 표시한 것
# 주사위를 100번 던져서 나오는 수들의 분포를 히스토그램으로 그려보기
np.random.seed(3)
a = np.random.randint(1,7, size = 100)
np.unique(a, return_counts=True) 

# hist(데이터 ,bins=가로의 구간개수)
plt.hist(a, bins = 6)
plt.show()

# %%
a
# Out:
# array([3, 1, 2, 4, 1, 1, 1, 6, 6, 4, 3, 4, 2, 2, 3, 6, 1, 5, 5, 6, 1, 3,
#        2, 3, 3, 3, 5, 2, 4, 3, 6, 1, 2, 6, 3, 1, 4, 1, 4, 2, 4, 1, 6, 5,
#        2, 6, 5, 5, 1, 1, 2, 3, 5, 6, 1, 1, 6, 6, 2, 2, 2, 6, 6, 3, 4, 5,
#        5, 4, 4, 1, 1, 1, 1, 3, 3, 4, 1, 6, 6, 1, 6, 2, 5, 2, 5, 3, 3, 5,
#        5, 3, 1, 5, 1, 4, 3, 1, 5, 4, 2, 6])

# %%
# 데이터 정제
# tdata 월 데이터 파생변수 만들기
tdata['월']=tdata['월일'].str[:2]
tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 0     \t2010-01-01  156     -3.6     -9.5      1.9  01-01  01
# 1     \t2010-01-02  156      1.6     -3.9      6.6  01-02  01
# 2     \t2010-01-03  156      0.4     -1.8      3.5  01-03  01
# 3     \t2010-01-04  156      0.5     -1.8      5.7  01-04  01
# 4     \t2010-01-05  156     -3.0     -4.9      0.2  01-05  01
# ...            ...  ...      ...      ...      ...    ...  ..
# 5154  \t2024-02-11  156      3.2     -1.2      9.1  02-11  02
# 5155  \t2024-02-12  156      5.8     -0.9     13.0  02-12  02
# 5156  \t2024-02-13  156     10.6      3.4     17.6  02-13  02
# 5157  \t2024-02-14  156     13.5     10.6     19.0  02-14  02
# 5158  \t2024-02-15  156      6.4      0.5     12.4  02-15  02
#
# [5159 rows x 7 columns]

# %%
# 2010~2024년 2월 데이터 최고기온을 히스토로 시각화
# 1. 2010~2024 2월 데이터 접근 --> 조건이므로 블리언
m2_tdata =tdata.query('월=="02"')
m2_tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 31    \t2010-02-01  156      3.6      0.5      7.9  02-01  02
# 32    \t2010-02-02  156     -0.6     -3.9      2.8  02-02  02
# 33    \t2010-02-03  156     -3.3     -5.4      0.4  02-03  02
# 34    \t2010-02-04  156     -1.4     -5.8      4.1  02-04  02
# 35    \t2010-02-05  156     -0.7     -4.3      4.4  02-05  02
# ...            ...  ...      ...      ...      ...    ...  ..
# 5154  \t2024-02-11  156      3.2     -1.2      9.1  02-11  02
# 5155  \t2024-02-12  156      5.8     -0.9     13.0  02-12  02
# 5156  \t2024-02-13  156     10.6      3.4     17.6  02-13  02
# 5157  \t2024-02-14  156     13.5     10.6     19.0  02-14  02
# 5158  \t2024-02-15  156      6.4      0.5     12.4  02-15  02
#
# [410 rows x 7 columns]

# %%
hist_tdata = m2_tdata['최고기온(℃)']

# %%
plt.hist(hist_tdata, bins = 100)
plt.show()

# %%
# 히스토그램 꾸미기
#color --> 색꾸미기
# alpha --> 투명도값(0~1사이 소수로~1에 가까우면 진함)
# label --> 지정가능
# 히스토도 겹치기 가능
plt.hist(m2_tdata['최저기온(℃)'],bins = 100,color='r',alpha=0.5,label='최저기온')

plt.hist(hist_tdata, bins = 100,color='g',alpha=0.5,label='최고기온')

plt.title('2월 최고/최저 기온')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### boxplot
# - box: 데이터의 사분위 범위를 나타내느 것 (2~3 분위의 데이터를 표시)
#
# - 수염의 의미 : 1사분위와 4사분위의 데이터
#
# - 박스안의 주황선 : 중앙값(평균값 아니다)
#
# - 점 의미 : 주로 수염 바깥쪽에 존재 -->이상치
#     - 중앙값,분위별 데이터 확인 이상치 데이터 확인

# %%
# 1D 데이터 준비하여 박스 플롯 그려보기
np.random.seed(1)
tmp_data = np.random.randint(10,size = 10)
print(tmp_data)
tmp_data= np.append(tmp_data, 20)
print(tmp_data)
plt.boxplot(tmp_data, labels=['데이터명'])
plt.show()
# Out:
# [5 8 9 5 0 0 1 7 6 9]
# [ 5  8  9  5  0  0  1  7  6  9 20]

# %%
tmp_data
# Out:
# array([5, 8, 9, 5, 0, 0, 1, 7, 6, 9])

# %%
m2_tdata['평균기온(℃)']
# Out:
# 31       3.6
# 32      -0.6
# 33      -3.3
# 34      -1.4
# 35      -0.7
#         ...
# 5154     3.2
# 5155     5.8
# 5156    10.6
# 5157    13.5
# 5158     6.4
# Name: 평균기온(℃), Length: 410, dtype: float64

# %%
# plt.boxplot(데이터,labels=['데이터명'])

# %%
plt.boxplot(m2_tdata['평균기온(℃)'],labels=['평균기온'])
plt.show()

# %%
m2_tdata[m2_tdata['평균기온(℃)']<-5]
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 762   \t2012-02-02  156     -7.9     -9.7     -5.2  02-02  02
# 768   \t2012-02-08  156     -5.7     -9.3     -2.0  02-08  02
# 1134  \t2013-02-08  156     -6.3     -9.7     -1.4  02-08  02
# 2956  \t2018-02-04  156     -5.9     -8.3     -3.0  02-04  02
# 2957  \t2018-02-05  156     -5.6     -8.5     -1.7  02-05  02
# 2958  \t2018-02-06  156     -6.5     -9.8     -2.8  02-06  02

# %%
m2_tdata[m2_tdata['평균기온(℃)']>14]
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일   월
# 54    \t2010-02-24  156     14.5      5.9     20.6  02-24  02
# 55    \t2010-02-25  156     15.9     14.5     18.6  02-25  02
# 2234  \t2016-02-13  156     14.2      6.5     19.8  02-13  02

# %% [markdown]
# ### barplot

# %%
# 데이터 준비하여 막대 그래프 그려보기
np.random.seed(6)
bar_x = np.arange(1,4)
bar_y = np.random.randint(50,100,size=3)
# plt.bar(x축,y축)
plt.bar(bar_x,bar_y)
plt.show()

# %%
# https://matplotlib.org/stable/gallery/color/named_colors.html#base-colors  doc제공 코드
import math
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


def plot_colortable(colors, *, ncols=4, sort_colors=True):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

# %%
plot_colortable(mcolors.CSS4_COLORS)
plt.show()

# %%
# barplot 꾸미기
# 색지정
plt.bar(bar_x,bar_y ,color='g')
plt.show()

# %%
# 색지정을 바별로 적용
# color=[]
plt.bar(bar_x,bar_y ,color=['limegreen','mediumslateblue','orange'])
plt.show()

# %%
bar_x
# Out:
# array([1, 2, 3])

# %%
bar_y
# Out:
# array([60, 59, 85])

# %%
# bar위에 데이터값 작성
# 매개변수 4개
# plt.text(x,y 축값,'string',fontdict={'color':'' , 'size' : 00 })

plt.bar(bar_x,bar_y ,color=['limegreen','mediumslateblue','orange'])

#plt.text(1,60, '60' ,fontdict={'color':'black' , 'size' :15})
#plt.text(2,59, '59' ,fontdict={'color':'black' , 'size' :15})
#plt.text(3,85, '85' ,fontdict={'color':'black' , 'size' :15})

# text(ha= va=)
# ha=호리젠탈 va=버티컬얼라이먼트
# ha=센터 왼 오른
# va=탑,바텀,센터,베이스라인,센터베이스라인
# 텍스가 기준으로 수직선 수평선을 방향이동-헷갈린다


for i in range(len(bar_x)):
    plt.text(bar_x[i],bar_y[i], bar_y[i] ,fontdict={'color':'black' , 'size' :15},ha='center',va='top')

plt.show()

# %%
economic = pd.read_csv('data/시도_성별_경제활동인구_총괄_KOSIS_2022.csv', encoding = 'euc-kr')
economic.head()
# Out:
#   행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 0    서울특별시  남자          4007         2849      2760        89          1158
# 1    서울특별시  여자          4440         2418      2347        72          2022
# 2    부산광역시  남자          1406          973       946        27           433
# 3    부산광역시  여자          1528          768       745        23           760
# 4    대구광역시  남자          1001          708       691        17           294
#
#    경제활동참가율(％)  고용률(%)  실업률(%)
# 0        71.1    68.9     3.1
# 1        54.5     NaN     3.0
# 2        69.2    67.3     2.7
# 3        50.3    48.8     3.0
# 4        70.6    69.0     2.3

# %%
#고용률(%) , 실업률(%)이 이상하다
economic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      34 non-null     object
#  1   성별            34 non-null     object
#  2   15세이상인구 (천명)  34 non-null     int64
#  3   경제활동인구 (천명)   34 non-null     int64
#  4   취업자 (천명)      34 non-null     int64
#  5   실업자 (천명)      34 non-null     int64
#  6   비경제활동인구 (천명)  34 non-null     int64
#  7   경제활동참가율(％)    34 non-null     float64
#  8   고용률(%)        24 non-null     float64
#  9   실업률(%)        28 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.8+ KB

# %%
economic['고용률(%)']


# 고용률 공식 = 취업자/15세이상 인구
# 넌값을 채우자
# 구한 값이 유사한지 보자 --> 같다
economic['고용률(%)']=economic['취업자 (천명)']/economic['15세이상인구 (천명)']*100
# 컬럼명은 그대로 하고 값을 채움
economic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      34 non-null     object
#  1   성별            34 non-null     object
#  2   15세이상인구 (천명)  34 non-null     int64
#  3   경제활동인구 (천명)   34 non-null     int64
#  4   취업자 (천명)      34 non-null     int64
#  5   실업자 (천명)      34 non-null     int64
#  6   비경제활동인구 (천명)  34 non-null     int64
#  7   경제활동참가율(％)    34 non-null     float64
#  8   고용률(%)        34 non-null     float64
#  9   실업률(%)        28 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.8+ KB

# %%
economic['실업률(%)']
# Out:
# 0     3.1
# 1     3.0
# 2     2.7
# 3     3.0
# 4     2.3
# 5     NaN
# 6     NaN
# 7     2.0
# 8     2.4
# 9     2.3
# 10    1.0
# 11    2.0
# 12    3.2
# 13    2.4
# 14    1.4
# 15    1.7
# 16    2.2
# 17    2.6
# 18    2.3
# 19    2.5
# 20    2.2
# 21    0.6
# 22    NaN
# 23    NaN
# 24    NaN
# 25    1.5
# 26    1.4
# 27    1.3
# 28    2.4
# 29    2.1
# 30    2.6
# 31    NaN
# 32    2.3
# 33    1.0
# Name: 실업률(%), dtype: float64

# %%
state_emp = economic[['행정구역(시도)','고용률(%)']].groupby('행정구역(시도)',as_index = False).mean()

state_emp.head()
# Out:
#   행정구역(시도)     고용률(%)
# 0      강원도  63.980543
# 1      경기도  64.251431
# 2     경상남도  61.391891
# 3     경상북도  64.097240
# 4    광주광역시  59.787050

# %%
# 5) 시도별 고용률 평균 막대 그래프로 시각화하고 고용률이 가장 높은 지역 확인
# Vertical Bar (수직 막대그래프)
plt.figure(figsize =(8,4))
plt.bar(state_emp['행정구역(시도)'],state_emp['고용률(%)'])
plt.xticks(rotation = 45)
plt.title('시도별 고용률 평균 시각화')
plt.xlabel('행정구역(시도)')
plt.ylabel('고용률(%)')
# ylim 크기 55~80 조절해서 확인
plt.ylim(55,80)
plt.show()
